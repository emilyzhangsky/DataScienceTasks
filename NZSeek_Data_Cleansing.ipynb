# %%
import pandas as pd
import re
import datetime

# %%
frame = pd.read_excel(r'NZ_Admin_JOBS.xlsx',header = None)

# %%
frame.head()
# Out:
#                                       0  \
# 0                         Administrator
# 1                          Receptionist
# 2          Prosecutions Support Officer
# 3  Early Childhood Centre Administrator
# 4        Business Support Administrator
#
#                                                    1  \
# 0  https://www.seek.co.nz/job/50582301?type=promo...
# 1  https://www.seek.co.nz/job/50620889?type=promo...
# 2  https://www.seek.co.nz/job/50622169?type=stand...
# 3  https://www.seek.co.nz/job/50639620?type=stand...
# 4  https://www.seek.co.nz/job/50622432?type=stand...
#
#                                           2  \
# 0                                       NaN
# 1                      Avenues Orthodontics
# 2                        New Zealand Police
# 3  Kew Pacific Island Early Learning Centre
# 4                                       NaN
#
#                                                    3  \
# 0  location: Bay of PlentyBay of Plentyarea: Taur...
# ...

# %%
frame.isnull().sum().sort_values(ascending = False)
# Out:
# 2    22
# 0     0
# 1     0
# 3     0
# 4     0
# 5     0
# dtype: int64

# %%
pd.set_option('display.max_colwidth', None)
frame[frame[3].str.contains(',')]
# Out:
#                                                            0  \
# 12                   Office Admin Assistant (10hrs per week)
# 17    Part-time Health & Disability Administrative Assistant
# 23                                   Reception/Administrator
# 25                                      Office Administrator
# 36                                      office administrator
# ...                                                      ...
# 2700                                     Executive Assistant
# 2701                                  Temporary Office Roles
# 2704                                     Executive Assistant
# 2705                                  Temporary Office Roles
# 2706                                  Temporary Office Roles
#
#                                                                                                               1  \
# 12    https://www.seek.co.nz/job/50597141?type=standard#searchRequestToken=feee129e-c80f-4f79-ac5f-98ddb6d6c22b
# ...

# %%
frame[3] = frame[3].str.split(',',expand = True)[0]
frame[3]
# Out:
# 0                     location: Bay of PlentyBay of Plentyarea: TaurangaTauranga
# 1                     location: Bay of PlentyBay of Plentyarea: TaurangaTauranga
# 2                                                     location: AucklandAuckland
# 3                     location: SouthlandSouthlandarea: InvercargillInvercargill
# 4                   location: CanterburyCanterburyarea: ChristchurchChristchurch
#                                           ...
# 2703            location: AucklandAucklandarea: Auckland CentralAuckland Central
# 2704    location: WellingtonWellingtonarea: Wellington CentralWellington Central
# 2705                              location: WaikatoWaikatoarea: HamiltonHamilton
# 2706                              location: WaikatoWaikatoarea: HamiltonHamilton
# 2707                                              location: WellingtonWellington
# Name: 3, Length: 2708, dtype: object

# %%
frame[['location','area']] = frame[3].str.split('area:',expand = True)
frame
# Out:
#                                          0  \
# 0                            Administrator
# 1                             Receptionist
# 2             Prosecutions Support Officer
# 3     Early Childhood Centre Administrator
# 4           Business Support Administrator
# ...                                    ...
# 2703                   Key Account Manager
# 2704                   Executive Assistant
# 2705                Temporary Office Roles
# 2706                Temporary Office Roles
# 2707                   Executive Assistant
#
#                                                                                                               1  \
# 0     https://www.seek.co.nz/job/50582301?type=promoted#searchRequestToken=feee129e-c80f-4f79-ac5f-98ddb6d6c22b
# 1     https://www.seek.co.nz/job/50620889?type=promoted#searchRequestToken=feee129e-c80f-4f79-ac5f-98ddb6d6c22b
# ...

# %%
frame['location'].isna().sum()
# Out:
# 0

# %%
frame['area'].isna().sum()
# Out:
# 541

# %%
frame['location'] = frame['location'].apply(lambda x:x[9:])
frame['location']
# Out:
# 0        Bay of PlentyBay of Plenty
# 1        Bay of PlentyBay of Plenty
# 2                  AucklandAuckland
# 3                SouthlandSouthland
# 4              CanterburyCanterbury
#                    ...
# 2703               AucklandAuckland
# 2704           WellingtonWellington
# 2705                 WaikatoWaikato
# 2706                 WaikatoWaikato
# 2707           WellingtonWellington
# Name: location, Length: 2708, dtype: object

# %%
def removeDuplication(x):
    trim = x.strip()
    index = (trim+trim).find(trim,1)
    if index != -1:
        return trim[0:index]

# %%
frame['location'] = frame['location'].apply(removeDuplication)

# %%
frame['location']
# Out:
# 0       Bay of Plenty
# 1       Bay of Plenty
# 2            Auckland
# 3           Southland
# 4          Canterbury
#             ...
# 2703         Auckland
# 2704       Wellington
# 2705          Waikato
# 2706          Waikato
# 2707       Wellington
# Name: location, Length: 2708, dtype: object

# %%
frame['area'].isna().sum()
# Out:
# 541

# %%
frame['area'].fillna(value = 'unknown', inplace = True)

# %%
frame['area']
# Out:
# 0                            TaurangaTauranga
# 1                            TaurangaTauranga
# 2                                     unknown
# 3                    InvercargillInvercargill
# 4                    ChristchurchChristchurch
#                         ...
# 2703         Auckland CentralAuckland Central
# 2704     Wellington CentralWellington Central
# 2705                         HamiltonHamilton
# 2706                         HamiltonHamilton
# 2707                                  unknown
# Name: area, Length: 2708, dtype: object

# %%
frame['area'] = frame['area'].apply(removeDuplication)
frame['area']
# Out:
# 0                 Tauranga
# 1                 Tauranga
# 2                  unknown
# 3             Invercargill
# 4             Christchurch
#                ...
# 2703      Auckland Central
# 2704    Wellington Central
# 2705              Hamilton
# 2706              Hamilton
# 2707               unknown
# Name: area, Length: 2708, dtype: object

# %%
frame.drop(3, axis = 1, inplace = True)

# %%
frame.head()
# Out:
#                                       0  \
# 0                         Administrator
# 1                          Receptionist
# 2          Prosecutions Support Officer
# 3  Early Childhood Centre Administrator
# 4        Business Support Administrator
#
#                                                                                                            1  \
# 0  https://www.seek.co.nz/job/50582301?type=promoted#searchRequestToken=feee129e-c80f-4f79-ac5f-98ddb6d6c22b
# 1  https://www.seek.co.nz/job/50620889?type=promoted#searchRequestToken=feee129e-c80f-4f79-ac5f-98ddb6d6c22b
# 2  https://www.seek.co.nz/job/50622169?type=standard#searchRequestToken=feee129e-c80f-4f79-ac5f-98ddb6d6c22b
# 3  https://www.seek.co.nz/job/50639620?type=standard#searchRequestToken=feee129e-c80f-4f79-ac5f-98ddb6d6c22b
# 4  https://www.seek.co.nz/job/50622432?type=standout#searchRequestToken=feee129e-c80f-4f79-ac5f-98ddb6d6c22b
#
# ...

# %%
frame[['classification','subClassification']] = frame[5].str.split('subClassification:',expand = True)
frame.head()
# Out:
#                                       0  \
# 0                         Administrator
# 1                          Receptionist
# 2          Prosecutions Support Officer
# 3  Early Childhood Centre Administrator
# 4        Business Support Administrator
#
#                                                                                                            1  \
# 0  https://www.seek.co.nz/job/50582301?type=promoted#searchRequestToken=feee129e-c80f-4f79-ac5f-98ddb6d6c22b
# 1  https://www.seek.co.nz/job/50620889?type=promoted#searchRequestToken=feee129e-c80f-4f79-ac5f-98ddb6d6c22b
# 2  https://www.seek.co.nz/job/50622169?type=standard#searchRequestToken=feee129e-c80f-4f79-ac5f-98ddb6d6c22b
# 3  https://www.seek.co.nz/job/50639620?type=standard#searchRequestToken=feee129e-c80f-4f79-ac5f-98ddb6d6c22b
# 4  https://www.seek.co.nz/job/50622432?type=standout#searchRequestToken=feee129e-c80f-4f79-ac5f-98ddb6d6c22b
#
# ...

# %%
frame['classification'].isna().sum()
# Out:
# 0

# %%
frame['subClassification'].isna().sum()
# Out:
# 603

# %%
frame['subClassification'].fillna(value='unknown',inplace = True)

# %%
frame['subClassification']
# Out:
# 0                                Office ManagementOffice Management
# 1                                        ReceptionistsReceptionists
# 2                                                        OtherOther
# 3                Administrative AssistantsAdministrative Assistants
# 4        Client & Sales AdministrationClient & Sales Administration
#                                    ...
# 2703     Client & Sales AdministrationClient & Sales Administration
# 2704                                                        unknown
# 2705                                                        unknown
# 2706                                                        unknown
# 2707                       PA, EA & SecretarialPA, EA & Secretarial
# Name: subClassification, Length: 2708, dtype: object

# %%
frame['subClassification'] = frame['subClassification'].apply(removeDuplication)
frame['subClassification']
# Out:
# 0                   Office Management
# 1                       Receptionists
# 2                               Other
# 3           Administrative Assistants
# 4       Client & Sales Administration
#                     ...
# 2703    Client & Sales Administration
# 2704                          unknown
# 2705                          unknown
# 2706                          unknown
# 2707             PA, EA & Secretarial
# Name: subClassification, Length: 2708, dtype: object

# %%
frame.drop(5, axis = 1, inplace = True)

# %%
frame.head()
# Out:
#                                       0  \
# 0                         Administrator
# 1                          Receptionist
# 2          Prosecutions Support Officer
# 3  Early Childhood Centre Administrator
# 4        Business Support Administrator
#
#                                                                                                            1  \
# 0  https://www.seek.co.nz/job/50582301?type=promoted#searchRequestToken=feee129e-c80f-4f79-ac5f-98ddb6d6c22b
# 1  https://www.seek.co.nz/job/50620889?type=promoted#searchRequestToken=feee129e-c80f-4f79-ac5f-98ddb6d6c22b
# 2  https://www.seek.co.nz/job/50622169?type=standard#searchRequestToken=feee129e-c80f-4f79-ac5f-98ddb6d6c22b
# 3  https://www.seek.co.nz/job/50639620?type=standard#searchRequestToken=feee129e-c80f-4f79-ac5f-98ddb6d6c22b
# 4  https://www.seek.co.nz/job/50622432?type=standout#searchRequestToken=feee129e-c80f-4f79-ac5f-98ddb6d6c22b
#
# ...

# %%
def find_salary(x):
    if 'classification:'in x:
        result = x
        return 'unknown'
    else:
        return x

# %%
frame['Salary'] = frame['classification'].apply(find_salary)

# %%
frame
# Out:
#                                          0  \
# 0                            Administrator
# 1                             Receptionist
# 2             Prosecutions Support Officer
# 3     Early Childhood Centre Administrator
# 4           Business Support Administrator
# ...                                    ...
# 2703                   Key Account Manager
# 2704                   Executive Assistant
# 2705                Temporary Office Roles
# 2706                Temporary Office Roles
# 2707                   Executive Assistant
#
#                                                                                                               1  \
# 0     https://www.seek.co.nz/job/50582301?type=promoted#searchRequestToken=feee129e-c80f-4f79-ac5f-98ddb6d6c22b
# 1     https://www.seek.co.nz/job/50620889?type=promoted#searchRequestToken=feee129e-c80f-4f79-ac5f-98ddb6d6c22b
# ...

# %%
frame['classification'] = frame['classification'].str.split('classification:',expand=True)[1]

# %%
frame['classification'].fillna(value='unknown', inplace=True)

# %%
frame['classification'] = frame['classification'].apply(removeDuplication)

# %%
frame[['classification1','classification2']] = frame['classification'].str.split('&', expand = True)

# %%
frame.drop('classification', axis = 1, inplace = True)

# %%
frame.head()
# Out:
#                                       0  \
# 0                         Administrator
# 1                          Receptionist
# 2          Prosecutions Support Officer
# 3  Early Childhood Centre Administrator
# 4        Business Support Administrator
#
#                                                                                                            1  \
# 0  https://www.seek.co.nz/job/50582301?type=promoted#searchRequestToken=feee129e-c80f-4f79-ac5f-98ddb6d6c22b
# 1  https://www.seek.co.nz/job/50620889?type=promoted#searchRequestToken=feee129e-c80f-4f79-ac5f-98ddb6d6c22b
# 2  https://www.seek.co.nz/job/50622169?type=standard#searchRequestToken=feee129e-c80f-4f79-ac5f-98ddb6d6c22b
# 3  https://www.seek.co.nz/job/50639620?type=standard#searchRequestToken=feee129e-c80f-4f79-ac5f-98ddb6d6c22b
# 4  https://www.seek.co.nz/job/50622432?type=standout#searchRequestToken=feee129e-c80f-4f79-ac5f-98ddb6d6c22b
#
# ...

# %%
frame[['postTime','featuredAt']] = frame[4].str.split(',', expand=True)[[0,2]]

# %%
frame.drop(4, axis = 1, inplace = True)

# %%
frame.head()
# Out:
#                                       0  \
# 0                         Administrator
# 1                          Receptionist
# 2          Prosecutions Support Officer
# 3  Early Childhood Centre Administrator
# 4        Business Support Administrator
#
#                                                                                                            1  \
# 0  https://www.seek.co.nz/job/50582301?type=promoted#searchRequestToken=feee129e-c80f-4f79-ac5f-98ddb6d6c22b
# 1  https://www.seek.co.nz/job/50620889?type=promoted#searchRequestToken=feee129e-c80f-4f79-ac5f-98ddb6d6c22b
# 2  https://www.seek.co.nz/job/50622169?type=standard#searchRequestToken=feee129e-c80f-4f79-ac5f-98ddb6d6c22b
# 3  https://www.seek.co.nz/job/50639620?type=standard#searchRequestToken=feee129e-c80f-4f79-ac5f-98ddb6d6c22b
# 4  https://www.seek.co.nz/job/50622432?type=standout#searchRequestToken=feee129e-c80f-4f79-ac5f-98ddb6d6c22b
#
# ...

# %%
frame['featuredAt'].isna().sum()
# Out:
# 2686

# %%
frame['featuredAt'].fillna(value = 'unknown', inplace = True)

# %%
frame
# Out:
#                                          0  \
# 0                            Administrator
# 1                             Receptionist
# 2             Prosecutions Support Officer
# 3     Early Childhood Centre Administrator
# 4           Business Support Administrator
# ...                                    ...
# 2703                   Key Account Manager
# 2704                   Executive Assistant
# 2705                Temporary Office Roles
# 2706                Temporary Office Roles
# 2707                   Executive Assistant
#
#                                                                                                               1  \
# 0     https://www.seek.co.nz/job/50582301?type=promoted#searchRequestToken=feee129e-c80f-4f79-ac5f-98ddb6d6c22b
# 1     https://www.seek.co.nz/job/50620889?type=promoted#searchRequestToken=feee129e-c80f-4f79-ac5f-98ddb6d6c22b
# ...

# %%
frame.rename(columns={0:'JobTitle', 1:'JobID', 2:'CompanyName'}, inplace = True)

# %%
frame
# Out:
#                                   JobTitle  \
# 0                            Administrator
# 1                             Receptionist
# 2             Prosecutions Support Officer
# 3     Early Childhood Centre Administrator
# 4           Business Support Administrator
# ...                                    ...
# 2703                   Key Account Manager
# 2704                   Executive Assistant
# 2705                Temporary Office Roles
# 2706                Temporary Office Roles
# 2707                   Executive Assistant
#
#                                                                                                           JobID  \
# 0     https://www.seek.co.nz/job/50582301?type=promoted#searchRequestToken=feee129e-c80f-4f79-ac5f-98ddb6d6c22b
# 1     https://www.seek.co.nz/job/50620889?type=promoted#searchRequestToken=feee129e-c80f-4f79-ac5f-98ddb6d6c22b
# ...

# %%
frame['CompanyName'].fillna(frame['featuredAt'], inplace = True)

# %%
frame
# Out:
#                                   JobTitle  \
# 0                            Administrator
# 1                             Receptionist
# 2             Prosecutions Support Officer
# 3     Early Childhood Centre Administrator
# 4           Business Support Administrator
# ...                                    ...
# 2703                   Key Account Manager
# 2704                   Executive Assistant
# 2705                Temporary Office Roles
# 2706                Temporary Office Roles
# 2707                   Executive Assistant
#
#                                                                                                           JobID  \
# 0     https://www.seek.co.nz/job/50582301?type=promoted#searchRequestToken=feee129e-c80f-4f79-ac5f-98ddb6d6c22b
# 1     https://www.seek.co.nz/job/50620889?type=promoted#searchRequestToken=feee129e-c80f-4f79-ac5f-98ddb6d6c22b
# ...

# %%
frame.drop('featuredAt', axis=1, inplace=True)

# %%
frame.head()
# Out:
#                                JobTitle  \
# 0                         Administrator
# 1                          Receptionist
# 2          Prosecutions Support Officer
# 3  Early Childhood Centre Administrator
# 4        Business Support Administrator
#
#                                                                                                        JobID  \
# 0  https://www.seek.co.nz/job/50582301?type=promoted#searchRequestToken=feee129e-c80f-4f79-ac5f-98ddb6d6c22b
# 1  https://www.seek.co.nz/job/50620889?type=promoted#searchRequestToken=feee129e-c80f-4f79-ac5f-98ddb6d6c22b
# 2  https://www.seek.co.nz/job/50622169?type=standard#searchRequestToken=feee129e-c80f-4f79-ac5f-98ddb6d6c22b
# 3  https://www.seek.co.nz/job/50639620?type=standard#searchRequestToken=feee129e-c80f-4f79-ac5f-98ddb6d6c22b
# 4  https://www.seek.co.nz/job/50622432?type=standout#searchRequestToken=feee129e-c80f-4f79-ac5f-98ddb6d6c22b
#
# ...

# %%
frame['CompanyName'].isna().sum()
# Out:
# 0

# %%
frame['postTime'] = frame['postTime'].str.extract('(\d+[a-z])')

# %%
frame
# Out:
#                                   JobTitle  \
# 0                            Administrator
# 1                             Receptionist
# 2             Prosecutions Support Officer
# 3     Early Childhood Centre Administrator
# 4           Business Support Administrator
# ...                                    ...
# 2703                   Key Account Manager
# 2704                   Executive Assistant
# 2705                Temporary Office Roles
# 2706                Temporary Office Roles
# 2707                   Executive Assistant
#
#                                                                                                           JobID  \
# 0     https://www.seek.co.nz/job/50582301?type=promoted#searchRequestToken=feee129e-c80f-4f79-ac5f-98ddb6d6c22b
# 1     https://www.seek.co.nz/job/50620889?type=promoted#searchRequestToken=feee129e-c80f-4f79-ac5f-98ddb6d6c22b
# ...

# %%
frame['postTime'].fillna(value='unknown', inplace=True)

# %%
frame['postTime'].dtypes
# Out:
# dtype('O')

# %%
frame['postTime'] = frame['postTime'].astype('string')

# %%
def PostTime(x):
    if 'd' in x:
        return -int(x[:-1])
    if 'm' in x:
        return -(int(x[:-1])*30)
    else:
        return 0

# %%
frame['postTime'] = frame['postTime'].apply(PostTime)

# %%
pd.set_option('display.max_rows', None)

# %%
frame[frame['Salary'].str.contains('\d', na=False)]['Salary']
# Out:
# 12                                            $20 per hour
# 17                                   $20 - $24.99 per hour
# 23                                     $19 to $22 per hour
# 25                                   $20 - $24.99 per hour
# 36                                   $20 - $24.99 per hour
# 42                                       $40,000 - $49,999
# 48                                            $25 per hour
# 58                             $60 000 - $70 000 per annum
# 59                                         $20.00 per hour
# 66                                   $20 - $24.99 per hour
# 75                                       $55,000 - $69,999
# 77                                        $20.00 per hour.
# 78                                   $20 - $24.99 per hour
# 81                                            $21 per hour
# 82                                       $55,000 - $64,999
# 89                         $50,000 - $55,000 plus benefits
# ...

# %%
frame['Salary'] = frame[frame['Salary'].str.contains('\d', na=False)]['Salary'].str.replace('Up to','-', regex = True)

# %%
frame['Salary'] = frame[frame['Salary'].str.contains('\d', na=False)]['Salary'].str.replace('to','-', regex = True)

# %%
frame[frame['Salary'].str.contains('\d', na=False)]['Salary']
# Out:
# 12                                            $20 per hour
# 17                                   $20 - $24.99 per hour
# 23                                      $19 - $22 per hour
# 25                                   $20 - $24.99 per hour
# 36                                   $20 - $24.99 per hour
# 42                                       $40,000 - $49,999
# 48                                            $25 per hour
# 58                             $60 000 - $70 000 per annum
# 59                                         $20.00 per hour
# 66                                   $20 - $24.99 per hour
# 75                                       $55,000 - $69,999
# 77                                        $20.00 per hour.
# 78                                   $20 - $24.99 per hour
# 81                                            $21 per hour
# 82                                       $55,000 - $64,999
# 89                         $50,000 - $55,000 plus benefits
# ...

# %%
frame['Salary'] = frame['Salary'].fillna('unknown')

# %%
frame['Salary'] = frame[frame['Salary'].str.contains('\d', na=False)]['Salary'].str.replace('\d\%','', regex = True)

# %%
frame['Salary'] = frame[frame['Salary'].str.contains('\d', na=False)]['Salary'].str.replace(',','', regex = True)

# %%
frame['Salary'] = frame[frame['Salary'].str.contains('\d', na=False)]['Salary'].str.replace(' ','', regex = True)

# %%
frame[['lowsalary','highsalary']] = frame['Salary'].str.split('-',expand = True)[[0,1]]
frame
# Out:
#                                                                           JobTitle  \
# 0                                                                    Administrator
# 1                                                                     Receptionist
# 2                                                     Prosecutions Support Officer
# 3                                             Early Childhood Centre Administrator
# 4                                                   Business Support Administrator
# 5                                                                  Support Officer
# 6                                                                  Support Officer
# 7                                                             office administrator
# 8                                                             Office Administrator
# 9                                                           Administration Officer
# ...

# %%
frame[frame['lowsalary'].str.contains('\d', na=False)]['lowsalary']
# Out:
# 12            $20perhour
# 17                   $20
# 23                   $19
# 25                   $20
# 36                   $20
# 42                $40000
# 48            $25perhour
# 58                $60000
# 59         $20.00perhour
# 66                   $20
# 75                $55000
# 77        $20.00perhour.
# 78                   $20
# 81            $21perhour
# 82                $55000
# 89                $50000
# 97                $45000
# 103               $55000
# 112                  $20
# 114                  $20
# 123               $48835
# 134                  $20
# 148                  $24
# 165               $50000
# 171                  $20
# 173                  $20
# 191                  $20
# 212               $55000
# 214               $40000
# 219               $45000
# 231                NZD25
# 247                  $20
# 264               $45000
# 277           $22perhour
# 278     NZD75000perannum
# 282                  $20
# 306                 $75k
# ...

# %%
frame['lowsalary'] = frame['lowsalary'].str.extract('(\d+\.\d+|\d+ \d+|\d+k|\d+)')

# %%
frame['highsalary'] = frame['highsalary'].str.extract('(\d+\.\d+|\d+ \d+|\d+k|\d+)')

# %%
frame['lowsalary'].fillna(value=0, inplace=True)

# %%
frame['highsalary'].fillna(value=0, inplace=True)

# %%
frame[frame['lowsalary'].str.contains('\d', na=False)]['lowsalary']
# Out:
# 12         20
# 17         20
# 23         19
# 25         20
# 36         20
# 42      40000
# 48         25
# 58      60000
# 59      20.00
# 66         20
# 75      55000
# 77      20.00
# 78         20
# 81         21
# 82      55000
# 89      50000
# 97      45000
# 103     55000
# 112        20
# 114        20
# 123     48835
# 134        20
# 148        24
# 165     50000
# 171        20
# 173        20
# 191        20
# 212     55000
# 214     40000
# 219     45000
# 231        25
# 247        20
# 264     45000
# 277        22
# 278     75000
# 282        20
# 306       75k
# 311        24
# 318     40000
# 319     50000
# 346     55000
# 349        20
# 379        20
# 384        30
# 393        45
# 398     50000
# 430     69726
# 442       60k
# 444     22.00
# 455     40000
# 458        27
# 459        60
# 464        19
# 473        60
# 478        35
# 482     55000
# 494        20
# 517        20
# 530        19
# 532     60000
# 533     40000
# 536        21
# ...

# %%
frame['lowsalary'] = frame['lowsalary'].str.replace('k','000', regex = True)

# %%
frame['highsalary'] = frame['highsalary'].str.replace('k','000', regex = True)

# %%
def salarytransform (x):
    if x < 1000:
        x = x * 8 * 250
    else :
        x = x
    return x

# %%
frame['lowsalary'] = frame['lowsalary'].astype('float32')

# %%
frame['highsalary'] = frame['highsalary'].astype('float32')

# %%
frame['lowsalary'] = frame['lowsalary'].apply(salarytransform)

# %%
frame['highsalary'] = frame['highsalary'].apply(salarytransform)

# %%
frame['lowsalary']
# Out:
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# 5            NaN
# 6            NaN
# 7            NaN
# 8            NaN
# 9            NaN
# 10           NaN
# 11           NaN
# 12       40000.0
# 13           NaN
# 14           NaN
# 15           NaN
# 16           NaN
# 17       40000.0
# 18           NaN
# 19           NaN
# 20           NaN
# 21           NaN
# 22           NaN
# 23       38000.0
# 24           NaN
# 25       40000.0
# 26           NaN
# 27           NaN
# 28           NaN
# 29           NaN
# 30           NaN
# 31           NaN
# 32           NaN
# 33           NaN
# 34           NaN
# 35           NaN
# 36       40000.0
# 37           NaN
# 38           NaN
# 39           NaN
# 40           NaN
# 41           NaN
# 42       40000.0
# 43           NaN
# 44           NaN
# 45           NaN
# 46           NaN
# 47           NaN
# 48       50000.0
# 49           NaN
# 50           NaN
# 51           NaN
# ...

# %%
frame['highsalary']
# Out:
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# 5                 NaN
# 6                 NaN
# 7                 NaN
# 8                 NaN
# 9                 NaN
# 10                NaN
# 11                NaN
# 12                NaN
# 13                NaN
# 14                NaN
# 15                NaN
# 16                NaN
# 17       49979.999542
# 18                NaN
# 19                NaN
# 20                NaN
# 21                NaN
# 22                NaN
# 23       44000.000000
# 24                NaN
# 25       49979.999542
# 26                NaN
# 27                NaN
# 28                NaN
# 29                NaN
# 30                NaN
# 31                NaN
# 32                NaN
# 33                NaN
# 34                NaN
# 35                NaN
# 36       49979.999542
# 37                NaN
# 38                NaN
# 39                NaN
# 40                NaN
# ...

# %%
frame['lowsalary'].fillna(value='unknown', inplace=True)

# %%
frame['highsalary'].fillna(value='unknown', inplace=True)

# %%
frame.drop('Salary', axis = 1, inplace = True)
